# %%
# Create a program capable of displaying questions to the user like KBC.
# Use List data type to store the questions and their correct answers.
# Display the final amount the person is taking home after playing the game.


# Project (KBC GAME)

print("KON BNEGA KRORPATI")
print()


# 1 Players Name
players = ["players name", "--------------", "1 HARRY", "2 SHRAHDA", "3 TONY STARK", "4 SPIDERMAN"]
# print(players)
for player in players:
    print(player)

print("\n")

# 2 Quetions and options
InventorOfPython = ["Question: InventorOfPython is...", "------------------------------------", "a. Guido Van Rossum()",
                    "b. Marks Zukerberg()", "c. Benjamin Franklin()", "d. james bond()"]
for inventor in InventorOfPython:
    print(inventor)

print("\n")

# 3 use define funtion
def a():
    print("correct ans: ", "a. Guido Van Rossum()")
    print("winner 10cr")

def b():
    print("INCORRECT ans: ", "b. Marks Zukerberg()")
    print("Thanks for participating")

def c():
    print("INCORRECT ans: ", "c. Benjamin Franklin()")
    print("Thanks for participating")

def d():
    print("INCORRECT ans: ", "d. james bond()")
    print("Thanks for participating")



# 4 use if-else
harry = str(input("enter option (a b c d ): harry choose -> "))
if harry == 'a':
    a()
elif harry == 'b':
    b()
elif harry == 'c':
    c()
elif harry == 'd':
    d()
print("\n")

shradha = str(input("enter option (a b c d ) : shradha choose -> "))
if shradha == 'a':
    a()
elif shradha == 'b':
    b()
elif shradha == 'c':
    c()
elif shradha == 'd':
    d()
print("\n")

tony_stark = str(input("enter option (a b c d ) : tony_stark choose -> "))
if tony_stark == 'a':
    a()
elif tony_stark == 'b':
    b()
elif tony_stark == 'c':
    c()
elif tony_stark == 'd':
    d()
print("\n")

spiderman = str(input("enter option (a b c d ) : spiderman choose -> "))
if spiderman == 'a':
    a()
elif spiderman == 'b':
    b()
elif spiderman == 'c':
    c()
elif spiderman == 'd':
    d()
# Out:
# KON BNEGA KRORPATI
#
# players name
# --------------
# 1 HARRY
# 2 SHRAHDA
# 3 TONY STARK
# 4 SPIDERMAN
#
#
# Question: InventorOfPython is...
# ------------------------------------
# a. Guido Van Rossum()
# b. Marks Zukerberg()
# c. Benjamin Franklin()
# d. james bond()
#
#
# enter option (a b c d ): harry choose -> a
# correct ans:  a. Guido Van Rossum()
# winner 10cr
#
#
# enter option (a b c d ) : shradha choose -> b
# INCORRECT ans:  b. Marks Zukerberg()
# Thanks for participating
#
#
# enter option (a b c d ) : tony_stark choose -> c
# INCORRECT ans:  c. Benjamin Franklin()
# Thanks for participating
#
#
# enter option (a b c d ) : spiderman choose -> d
# INCORRECT ans:  d. james bond()
# Thanks for participating

# %%
harry = int(input("enter option number : "))
if harry == 1:
    print("True")

    
# NOTE: INT FOR NUMBER. true print ni hoga agar number me quote lgayenge to.
# output:
# enter option number : 1
# True

# %%
harry = str(input("enter option number : "))
if harry == 'a':
    print("True")
   

# note: STR FOR STRING. 
# output:
# enter option number : a
# True
