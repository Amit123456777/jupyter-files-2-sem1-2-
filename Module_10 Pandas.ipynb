# %%
# It was created by wes msckinney in 2006

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # # Series

# %%
import pandas as pd
a = pd.Series()
print(a)
# Out:
# Series([], dtype: object)

# %%
# code 
import pandas as pd
x = [1,2,37,6,5]
var = pd.Series(x)
var
# Out:
# 0     1
# 1     2
# 2    37
# 3     6
# 4     5
# dtype: int64

# %%
type(var)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Index

# %%
var = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
var
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# # name parameter

# %%
var = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'], name = 'Python')
var
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Python, dtype: int64

# %% [markdown]
# # create series using dictionary

# %%
dic = {"name":["python", "java", "html", "c"], "rank" : [95, 92, 85,86]}
var1 = pd.Series(dic)
var1
# Out:
# name    [python, java, html, c]
# rank           [95, 92, 85, 86]
# dtype: object

# %% [markdown]
# # single data series

# %%
s = pd.Series(12)
print(s)
print(type(s))
# Out:
# 0    12
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # creating multi series of same data

# %%
s = pd.Series(12, index = [1,2,3,4,5,6,7])
s
# Out:
# 1    12
# 2    12
# 3    12
# 4    12
# 5    12
# 6    12
# 7    12
# dtype: int64

# %% [markdown]
# # Add two series

# %%
s1 = pd.Series(12, index = [1,2,3,4,5,6])
s2 = pd.Series(12, index = [1,2,3,4,5,6,])
print(s1+s2)
# Out:
# 1    24
# 2    24
# 3    24
# 4    24
# 5    24
# 6    24
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
# create dataframe

# %%
# 1 with the help of list
# 2 with the dictionary

# %%
import pandas as pd
l = [1,2,3,4,5]
var = pd.DataFrame(l)
print(var)
print(type(var))
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
# <class 'pandas.core.frame.DataFrame'>

# %%
# using dict
d = {"a" : [1,2,3], "b":[4,5,6], "c":[7,8,9]}
var1 = pd.DataFrame(d)
var1
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# # show particular column

# %%
d = {"a" : [1,2,3], "b":[4,5,6], "c":[7,8,9]}
var1 = pd.DataFrame(d, columns = ["a"])
var1
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %% [markdown]
# # Index

# %%
d = {"a" : [1,2,3], "b":[4,5,6], "c":[7,8,9]}
var1 = pd.DataFrame(d, columns = ["a"], index = ["a","b","c"])
var1
# Out:
#    a
# a  1
# b  2
# c  3

# %% [markdown]
# # get particular data

# %%
d = {"a":[1,2,3,4], "b":[10,20,30,40], "c":[20,21,22,23]}
var2 = pd.DataFrame(d)
var2
# Out:
#    a   b   c
# 0  1  10  20
# 1  2  20  21
# 2  3  30  22
# 3  4  40  23

# %%
var2["b"][1]
# Out:
# 20

# %% [markdown]
# # creation of df using list

# %%
lst = [[1,2,3,4], [5,6,7,8]]
var2 = pd.DataFrame(lst)
var2
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8

# %% [markdown]
# # creation df using series

# %%
s1 = {"s":pd.Series([1,2,3,4]), "r":pd.Series([1,2,3,4])}
var3 = pd.DataFrame(s1)
var3
# Out:
#    s  r
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4

# %% [markdown]
# # Arithmetic Operations

# %%
import pandas as pd
var = pd.DataFrame({"A": [1,2,3,4], "B" : [5,6,7,8]})
var
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %% [markdown]
# # add another column

# %%
var["C"] = [1,2,3,4]

# %%
var
# Out:
#    A  B  C
# 0  1  5  1
# 1  2  6  2
# 2  3  7  3
# 3  4  8  4

# %% [markdown]
# # add column a and b

# %%
var["A+B"] = var["A"] + var["B"]
var
# Out:
#    A  B  C   D  A+B
# 0  1  5  1   6    6
# 1  2  6  2   8    8
# 2  3  7  3  10   10
# 3  4  8  4  12   12

# %% [markdown]
# # logical operators in df

# %%
var["python"] = var["A"] <= 2
var
# Out:
#    A  B  C   D  A+B  python
# 0  1  5  1   6    6    True
# 1  2  6  2   8    8    True
# 2  3  7  3  10   10   False
# 3  4  8  4  12   12   False

# %% [markdown]
# # DELETE and INSERT FUNCTIONS

# %% [markdown]
# # INSERT

# %%
import pandas as pd
var = pd.DataFrame({"A" : [1,2,3,4], "B" : [5,6,7,8]})
var
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
# now insert
# 3 parameter
var.insert(1, "C", [1,2,3,4])  # index, col_nama, data
var
# Out:
#    A  C  B
# 0  1  1  5
# 1  2  2  6
# 2  3  3  7
# 3  4  4  8

# %% [markdown]
# # pop

# %%
var1= pd.DataFrame({"A" : [1,2,3,4], "B" : [5,6,7,8], "C": [10,20,30,40]})
var1.pop("C")
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: C, dtype: int64

# %%
var1
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %% [markdown]
# # del []

# %%
del var1["A"]

# %%
var1
# Out:
#    B
# 0  5
# 1  6
# 2  7
# 3  8

# %% [markdown]
# # READ CSV

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Rahul\\Downloads\\archive(1)\\Dropout.csv")
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                              1                       1            1
# ...

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
df.head(10)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
# 5               2                12                  1      17
# 6               1                 1                  1      12
# 7               1                 9                  4      11
# 8               1                 1                  3      10
# 9               1                 1                  1      10
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# ...

# %%
df.tail()
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 4419                           1                       1            1
# 4420                           1                       1           19
# 4421                           1                       1            1
# 4422                           1                       1            1
# 4423                           1                       1            9
#
#       Mother's qualification  Father's qualification  Mother's occupation  \
# ...

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nacionality  \
# count                 4424.000000             4424.000000  4424.000000
# mean                     0.890823                2.531420     1.254521
# std                      0.311897                3.963707     1.748447
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %% [markdown]
# # ILoc

# %%
# value = df.iloc[row,col]
value = df.iloc[1,1]
value
# Out:
# 6

# %%
df.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
# ...

# %% [markdown]
# # sort

# %%
df.sort_values(by="Application mode")
# Out:
#       Marital status  Application mode  Application order  Course  \
# 2211               1                 1                  1       5
# 2791               1                 1                  1       6
# 1226               1                 1                  1       9
# 2793               1                 1                  1       2
# 1224               1                 1                  3      12
# ...              ...               ...                ...     ...
# 1348               1                17                  1       6
# 2383               1                17                  1       4
# 560                1                17                  1       4
# 2345               1                17                  1       6
# 2041               2                18                  1      17
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 2211                           1                       1            1
# ...

# %% [markdown]
# # group by

# %%
data = {
    "category":["A","B","A","B","A"],
    "value":[10,20,30,40,50]
}
df = pd.DataFrame(data)

grouped_df = df.groupby('category').sum()
print(grouped_df)
# Out:
#           value
# category
# A            90
# B            60
